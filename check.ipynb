# %%
import sys
sys.path.append("./src")

from metaflow import Flow
from IPython.display import Image

# %%
run = Flow('ClassifierTrainFlow').latest_run

# %%
run['start'].task.data
# Out:
# <MetaflowData: test_data, test_labels, name, vis, train_data, models, train_labels>

# %%
Image(run['start'].task.data.vis)

# %%
model = run['eval'].task.data.model

# %%
model.predict([[5.8, 2.8, 5.1, 2.4]])
# Out:
# array([2])
